# %% [markdown]
# # jacutinga

# %% [raw]
# inicio do projeto

# %%
import weather, pandas as pd

# %%
df = weather.carregar_dados()
# Out:
# {'data': datetime.datetime(2023, 10, 1, 8, 15), 'latitude': -22.925, 'longitude': -45.87, 'temperatura': 17.33000000000004, 'sensacao_termica': 17.629999999999995, 'pressao': 1015, 'umidade': 96, 'nuvens': 90, 'vento_velocidade': 1.94, 'vento_direcao': 5, 'nascer_sol': datetime.datetime(2023, 10, 1, 5, 44, 17), 'condicao_clima': 'Rain', 'descricao_clima': 'light rain', 'por_sol': datetime.datetime(2023, 10, 1, 18, 2, 3)}
# {'data': datetime.datetime(2023, 10, 1, 9, 30), 'latitude': -22.91, 'longitude': -45.855, 'temperatura': 18.090000000000032, 'sensacao_termica': 18.439999999999998, 'pressao': 1015, 'umidade': 95, 'nuvens': 99, 'vento_velocidade': 2.1, 'vento_direcao': 342, 'nascer_sol': datetime.datetime(2023, 10, 1, 5, 44, 13), 'condicao_clima': 'Rain', 'descricao_clima': 'moderate rain', 'por_sol': datetime.datetime(2023, 10, 1, 18, 1, 59)}
# ...

# %%
df
# Out:
#              data_hora  latitude  longitude nome_ave                data  \
# 0  2023-10-01 08:15:00   -22.925    -45.870     Saci 2023-10-01 08:15:00
# 1  2023-10-01 09:30:00   -22.910    -45.855     Mimi 2023-10-01 09:30:00
# 2  2023-10-01 10:45:00   -22.930    -45.860    Pluto 2023-10-01 10:45:00
# 3  2023-10-02 08:20:00   -22.920    -45.850     Mimi 2023-10-02 08:20:00
# 4  2023-10-02 07:00:00   -22.915    -45.865     Saci 2023-10-02 07:00:00
# 5  2023-10-02 09:35:00   -22.905    -45.862    Pluto 2023-10-02 09:35:00
# 6  2023-10-03 10:00:00   -22.918    -45.875     Saci 2023-10-03 10:00:00
# 7  2023-10-03 12:30:00   -22.928    -45.863    Pluto 2023-10-03 12:30:00
# 8  2023-10-03 11:15:00   -22.912    -45.858     Mimi 2023-10-03 11:15:00
# 9  2023-10-04 13:45:00   -22.922    -45.867     Saci 2023-10-04 13:45:00
#
#    temperatura  sensacao_termica  pressao  umidade  nuvens  vento_velocidade  \
# 0        17.33             17.63     1015       96      90              1.94
# ...

# %%
print(df.groupby("nome_ave").agg({"temperatura": ["mean", "min", "max"]}))
# Out:
#          temperatura
#                 mean    min    max
# nome_ave
# Mimi       20.043333  18.09  22.59
# Pluto      21.233333  19.31  24.97
# Saci       20.260000  16.78  27.93

# %% [markdown]
# o que notamos com os dados é que na condicao tal o saci mais visto que a Mimi

# %%
print(df.groupby("condicao_clima").agg({"temperatura": ["mean", "min", "max"]}))
# Out:
#                temperatura
#                       mean    min    max
# condicao_clima
# Clouds           20.861667  16.78  27.93
# Rain             19.925000  17.33  24.97

# %%
df.T
# Out:
#                                     0                    1  \
# data_hora         2023-10-01 08:15:00  2023-10-01 09:30:00
# latitude                      -22.925               -22.91
# longitude                      -45.87              -45.855
# nome_ave                         Saci                 Mimi
# data              2023-10-01 08:15:00  2023-10-01 09:30:00
# temperatura                     17.33                18.09
# sensacao_termica                17.63                18.44
# pressao                          1015                 1015
# umidade                            96                   95
# nuvens                             90                   99
# vento_velocidade                 1.94                  2.1
# vento_direcao                       5                  342
# nascer_sol        2023-10-01 05:44:17  2023-10-01 05:44:13
# condicao_clima                   Rain                 Rain
# descricao_clima            light rain        moderate rain
# ...

# %%
len(df)
# Out:
# 10

# %%
print(df)
# Out:
#              data_hora  latitude  longitude nome_ave                data  \
# 0  2023-10-01 08:15:00   -22.925    -45.870     Saci 2023-10-01 08:15:00
# 1  2023-10-01 09:30:00   -22.910    -45.855     Mimi 2023-10-01 09:30:00
# 2  2023-10-01 10:45:00   -22.930    -45.860    Pluto 2023-10-01 10:45:00
# 3  2023-10-02 08:20:00   -22.920    -45.850     Mimi 2023-10-02 08:20:00
# 4  2023-10-02 07:00:00   -22.915    -45.865     Saci 2023-10-02 07:00:00
# 5  2023-10-02 09:35:00   -22.905    -45.862    Pluto 2023-10-02 09:35:00
# 6  2023-10-03 10:00:00   -22.918    -45.875     Saci 2023-10-03 10:00:00
# 7  2023-10-03 12:30:00   -22.928    -45.863    Pluto 2023-10-03 12:30:00
# 8  2023-10-03 11:15:00   -22.912    -45.858     Mimi 2023-10-03 11:15:00
# 9  2023-10-04 13:45:00   -22.922    -45.867     Saci 2023-10-04 13:45:00
#
#    temperatura  sensacao_termica  pressao  umidade  nuvens  vento_velocidade  \
# 0        17.33             17.63     1015       96      90              1.94
# ...

# %%
df = df.T

# %%
print(df)
# Out:
#                                     0                    1  \
# data_hora         2023-10-01 08:15:00  2023-10-01 09:30:00
# latitude                      -22.925               -22.91
# longitude                      -45.87              -45.855
# nome_ave                         Saci                 Mimi
# data              2023-10-01 08:15:00  2023-10-01 09:30:00
# temperatura                     17.33                18.09
# sensacao_termica                17.63                18.44
# pressao                          1015                 1015
# umidade                            96                   95
# nuvens                             90                   99
# vento_velocidade                 1.94                  2.1
# vento_direcao                       5                  342
# nascer_sol        2023-10-01 05:44:17  2023-10-01 05:44:13
# condicao_clima                   Rain                 Rain
# descricao_clima            light rain        moderate rain
# ...

# %%
df
# Out:
#                                     0                    1  \
# data_hora         2023-10-01 08:15:00  2023-10-01 09:30:00
# latitude                      -22.925               -22.91
# longitude                      -45.87              -45.855
# nome_ave                         Saci                 Mimi
# data              2023-10-01 08:15:00  2023-10-01 09:30:00
# temperatura                     17.33                18.09
# sensacao_termica                17.63                18.44
# pressao                          1015                 1015
# umidade                            96                   95
# nuvens                             90                   99
# vento_velocidade                 1.94                  2.1
# vento_direcao                       5                  342
# nascer_sol        2023-10-01 05:44:17  2023-10-01 05:44:13
# condicao_clima                   Rain                 Rain
# descricao_clima            light rain        moderate rain
# ...

# %%
df = df.T

# %%
df
# Out:
#              data_hora latitude longitude nome_ave                 data  \
# 0  2023-10-01 08:15:00  -22.925    -45.87     Saci  2023-10-01 08:15:00
# 1  2023-10-01 09:30:00   -22.91   -45.855     Mimi  2023-10-01 09:30:00
# 2  2023-10-01 10:45:00   -22.93    -45.86    Pluto  2023-10-01 10:45:00
# 3  2023-10-02 08:20:00   -22.92    -45.85     Mimi  2023-10-02 08:20:00
# 4  2023-10-02 07:00:00  -22.915   -45.865     Saci  2023-10-02 07:00:00
# 5  2023-10-02 09:35:00  -22.905   -45.862    Pluto  2023-10-02 09:35:00
# 6  2023-10-03 10:00:00  -22.918   -45.875     Saci  2023-10-03 10:00:00
# 7  2023-10-03 12:30:00  -22.928   -45.863    Pluto  2023-10-03 12:30:00
# 8  2023-10-03 11:15:00  -22.912   -45.858     Mimi  2023-10-03 11:15:00
# 9  2023-10-04 13:45:00  -22.922   -45.867     Saci  2023-10-04 13:45:00
#
#   temperatura sensacao_termica pressao umidade nuvens vento_velocidade  \
# 0       17.33            17.63    1015      96     90             1.94
# ...

# %%
len(df)
# Out:
# 10

# %%
df.shape
# Out:
# (10, 16)

# %%
df.head()
# Out:
#              data_hora latitude longitude nome_ave                 data  \
# 0  2023-10-01 08:15:00  -22.925    -45.87     Saci  2023-10-01 08:15:00
# 1  2023-10-01 09:30:00   -22.91   -45.855     Mimi  2023-10-01 09:30:00
# 2  2023-10-01 10:45:00   -22.93    -45.86    Pluto  2023-10-01 10:45:00
# 3  2023-10-02 08:20:00   -22.92    -45.85     Mimi  2023-10-02 08:20:00
# 4  2023-10-02 07:00:00  -22.915   -45.865     Saci  2023-10-02 07:00:00
#
#   temperatura sensacao_termica pressao umidade nuvens vento_velocidade  \
# 0       17.33            17.63    1015      96     90             1.94
# 1       18.09            18.44    1015      95     99              2.1
# 2       19.31             19.7    1015      92     94             1.97
# 3       19.45            19.88    1014      93    100             0.49
# 4       16.78            17.02    1014      96    100             0.61
#
#   vento_direcao           nascer_sol condicao_clima  descricao_clima  \
# ...

# %%
df.tail()
# Out:
#              data_hora latitude longitude nome_ave                 data  \
# 5  2023-10-02 09:35:00  -22.905   -45.862    Pluto  2023-10-02 09:35:00
# 6  2023-10-03 10:00:00  -22.918   -45.875     Saci  2023-10-03 10:00:00
# 7  2023-10-03 12:30:00  -22.928   -45.863    Pluto  2023-10-03 12:30:00
# 8  2023-10-03 11:15:00  -22.912   -45.858     Mimi  2023-10-03 11:15:00
# 9  2023-10-04 13:45:00  -22.922   -45.867     Saci  2023-10-04 13:45:00
#
#   temperatura sensacao_termica pressao umidade nuvens vento_velocidade  \
# 5       19.42            19.66    1014      86     96             1.06
# 6        19.0            19.18    1015      85     88             0.67
# 7       24.97            25.35    1011      70     42             2.19
# 8       22.59            22.99    1014      80     56             1.19
# 9       27.93            29.03    1007      57     99             3.31
#
#   vento_direcao           nascer_sol condicao_clima  descricao_clima  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_hora         10 non-null     object
#  1   latitude          10 non-null     object
#  2   longitude         10 non-null     object
#  3   nome_ave          10 non-null     object
#  4   data              10 non-null     object
#  5   temperatura       10 non-null     object
#  6   sensacao_termica  10 non-null     object
#  7   pressao           10 non-null     object
#  8   umidade           10 non-null     object
#  9   nuvens            10 non-null     object
#  10  vento_velocidade  10 non-null     object
#  11  vento_direcao     10 non-null     object
#  12  nascer_sol        10 non-null     object
#  13  condicao_clima    10 non-null     object
#  14  descricao_clima   10 non-null     object
#  15  por_sol           10 non-null     object
# dtypes: object(16)
# ...

# %%
df.describe()
# Out:
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_24764\3627053830.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   df.describe()
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_24764\3627053830.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   df.describe()
# C:\Users\yasmi\AppData\Local\Temp\ipykernel_24764\3627053830.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   df.describe()
# ...

# %%
df ["descricao_clima"].value_counts()
# Out:
# descricao_clima
# overcast clouds    5
# light rain         2
# moderate rain      2
# broken clouds      1
# Name: count, dtype: int64

# %%
df.loc[df["nome_ave"] == "Mimi", "descricao_clima"].value_counts()
# Out:
# descricao_clima
# moderate rain      1
# overcast clouds    1
# broken clouds      1
# Name: count, dtype: int64
